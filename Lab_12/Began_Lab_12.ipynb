# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np

# load dataset
data = pd.read_csv("BostonHousing.csv")
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#scatter plot.
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 8))
plt.scatter(data['rm'],data['medv'],c='black')
plt.xlabel("average number of rooms per dwelling.")
plt.ylabel("median value of owner-occupied homes in \\$1000s.")
plt.show()

# %%
#Feature selection :split dataset
X = data['rm']
y = data['medv']

# %%
# Fit and make the predictions by the model
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared (uncentered):                   0.901
# Model:                            OLS   Adj. R-squared (uncentered):              0.901
# Method:                 Least Squares   F-statistic:                              4615.
# Date:                Tue, 25 Mar 2025   Prob (F-statistic):                   3.74e-256
# Time:                        15:27:09   Log-Likelihood:                         -1747.1
# No. Observations:                 506   AIC:                                      3496.
# Df Residuals:                     505   BIC:                                      3500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#What are the key components of the model summary provided by statsmodels (e.g., R-squared, coefficients, p-values)?
# R^2 = .901 coef = 3.6534 f-statistic = 4615 Prob(f-stat) = 3.74e-256
#How would you interpret the slope coefficient in this context?
# the coef is 3.6534 and means the slop is positive at over a 3 to 1 rate of increase
