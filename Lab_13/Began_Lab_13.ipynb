# %%
# Importing required libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
# load dataset
data = pd.read_csv("Advertising.csv")
print(data.head())
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# Preprocessing data
data.drop(['Unnamed: 0'], axis=1)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
#scatter plot.
plt.figure(figsize=(16, 8))
plt.scatter(data['TV'],data['Sales'],c='black')
plt.xlabel("Money spent on TV ads ($)")
plt.ylabel("Sales ($)")
plt.show()

# %%
#Feature selection :split dataset
X = data['TV'].values.reshape(-1,1)
y = data['Sales'].values.reshape(-1,1)
print("\n -------------Simple Linear Regression--------------\n \n")
reg = LinearRegression()
reg.fit(X, y)
print("The linear model is: Y = {:.5} + {:.5}X\n\n".format(reg.intercept_[0], reg.coef_[0][0]))
# Out:
#  -------------Simple Linear Regression--------------
#
#
# The linear model is: Y = 7.0326 + 0.047537X

# %%
predictions = reg.predict(X)
plt.figure(figsize=(16, 8))
plt.scatter(data['TV'],data['Sales'], c='black')
plt.plot(data['TV'],predictions, c='blue',linewidth=2)
plt.xlabel("Money spent on TV ads ($)")
plt.ylabel("Sales ($)")
plt.show()

# %%
#Assessing the relevancy of the model
X = data['TV']
y = data['Sales']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Thu, 27 Mar 2025   Prob (F-statistic):           1.47e-42
# Time:                        15:36:06   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
#Multiple Linear Regression
print("\n ------------------------------------Multiple Linear Regression------------------------\n \n")
#Feature selection :split dataset
Xs = data.drop(['Sales', 'Unnamed: 0'], axis=1)
y = data['Sales']. values.reshape(-1,1)
reg = LinearRegression()
reg.fit(Xs, y)
print("The linear model is: Y = {:.5} + {:.5}*TV + {:.5}*radio + {:.5}*newspaper\n\n".format(reg.intercept_[0], reg.coef_[0][0], reg.coef_[0][1], reg.coef_[0][2]))
# Out:
#  ------------------------------------Multiple Linear Regression------------------------
#
#
# The linear model is: Y = 2.9389 + 0.045765*TV + 0.18853*radio + -0.0010375*newspaper

# %%
#Assessing the relevancy of the model
X = np.column_stack((data['TV'], data['Radio'], data['Newspaper']))
y = data['Sales']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 27 Mar 2025   Prob (F-statistic):           1.58e-96
# Time:                        15:36:53   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
print("\n -------------------Drop Newspaper-------------\n \n")
#Feature selection :split dataset
Xs = data.drop(['Sales', 'Newspaper', 'Unnamed: 0'], axis=1)
y = data['Sales']. values.reshape(-1,1)
reg = LinearRegression()
reg.fit(Xs, y)
print("The linear model is: Y = {:.5} + {:.5}*TV + {:.5}*radio\n\n".format(reg.intercept_[0], reg.coef_[0][0], reg.coef_[0][1]))
# Out:
#  -------------------Drop Newspaper-------------
#
#
# The linear model is: Y = 2.9211 + 0.045755*TV + 0.18799*radio

# %%
#Assessing the relevancy of the model
X = np.column_stack((data['TV'], data['Radio']))
y = data['Sales']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()

# %%
#1. In what scenarios might it be more appropriate to use multiple regression analysis over simple linear regression, and what additional insights can it provide?
#       Multiple regressions help to understand the relationship between 1 dependent and multiple independent variables
#2. Explain the role of the p-value associated with the slope coefficient.
#       the p-value allows for testing the null hypothesis for rejection or failure to reject null hypothesis. 
#3. How can you fine-tune model parameters to optimize performance in a specific context?
#       the exog parameter in OLS of statsmodel where nobs is the number of observations and k is the number of regressors. 
#4. Submit your solutions, Python source code, and a screenshot of your output
